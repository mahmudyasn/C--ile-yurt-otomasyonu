-- %% [markdown]
-- # [OgrYurt]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [OgrYurt]    Script Date: 18.01.2022 23:13:36 ******/
CREATE DATABASE [OgrYurt]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'OgrYurt', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\OgrYurt.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'OgrYurt_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\OgrYurt_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [OgrYurt].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [OgrYurt] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [OgrYurt] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [OgrYurt] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [OgrYurt] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [OgrYurt] SET ARITHABORT OFF 
GO
ALTER DATABASE [OgrYurt] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [OgrYurt] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [OgrYurt] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [OgrYurt] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [OgrYurt] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [OgrYurt] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [OgrYurt] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [OgrYurt] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [OgrYurt] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [OgrYurt] SET  DISABLE_BROKER 
GO
ALTER DATABASE [OgrYurt] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [OgrYurt] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [OgrYurt] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [OgrYurt] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [OgrYurt] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [OgrYurt] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [OgrYurt] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [OgrYurt] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [OgrYurt] SET  MULTI_USER 
GO
ALTER DATABASE [OgrYurt] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [OgrYurt] SET DB_CHAINING OFF 
GO
ALTER DATABASE [OgrYurt] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [OgrYurt] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [OgrYurt] SET DELAYED_DURABILITY = DISABLED 
GO

-- %% [markdown]
-- # [YurtKullanici]

-- %%
USE [OgrYurt]
GO

-- %%
/****** Object:  User [YurtKullanici]    Script Date: 18.01.2022 23:13:36 ******/
CREATE USER [YurtKullanici] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [kyurt]

-- %%
/****** Object:  User [kyurt]    Script Date: 18.01.2022 23:13:36 ******/
CREATE USER [kyurt] FOR LOGIN [kyurt] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [YurtKullanici]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [YurtKullanici]
GO

-- %% [markdown]
-- # [kyurt]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [kyurt]
GO

-- %% [markdown]
-- # [dbo].[Log]

-- %%
/****** Object:  Table [dbo].[Log]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Log](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LogIcerik] [nvarchar](max) NULL,
	[PersonelID] [int] NULL,
	[IslemTarihi] [datetime] NULL,
 CONSTRAINT [PK_Log] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Oda]

-- %%
/****** Object:  Table [dbo].[Oda]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Oda](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OdaNo] [nvarchar](10) NOT NULL,
	[KisiSayisi] [int] NOT NULL,
	[Durum] [bit] NOT NULL,
 CONSTRAINT [PK_Oda] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Odeme]

-- %%
/****** Object:  Table [dbo].[Odeme]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Odeme](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OdemeTutari] [float] NOT NULL,
	[IslemTarihi] [datetime] NOT NULL,
	[PersonelID] [int] NOT NULL,
	[UcretID] [int] NOT NULL,
 CONSTRAINT [PK_Odeme] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ogrenci]

-- %%
/****** Object:  Table [dbo].[Ogrenci]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ogrenci](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OdaID] [int] NOT NULL,
	[Ad] [nvarchar](20) NOT NULL,
	[Soyad] [nvarchar](20) NOT NULL,
	[TC] [nchar](11) NOT NULL,
	[Telefon] [nchar](11) NULL,
	[Resim] [varbinary](max) NULL,
	[KayitTarihi] [datetime] NOT NULL,
	[OgrenciNo] [nvarchar](15) NOT NULL,
	[OgrSinif] [int] NOT NULL,
	[Durum] [bit] NOT NULL,
 CONSTRAINT [PK_Ogrenci] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Personel]

-- %%
/****** Object:  Table [dbo].[Personel]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Personel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](50) NOT NULL,
	[Soyad] [nvarchar](50) NOT NULL,
	[Telefon] [nvarchar](11) NULL,
	[KullaniciAdi] [nvarchar](20) NOT NULL,
	[Sifre] [nvarchar](10) NOT NULL,
	[KayitTarihi] [datetime] NOT NULL,
	[Durum] [bit] NOT NULL,
 CONSTRAINT [PK_Personel] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ucret]

-- %%
/****** Object:  Table [dbo].[Ucret]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ucret](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OgrenciID] [int] NOT NULL,
	[KayitBaslangicTarihi] [datetime] NOT NULL,
	[TaksitSayisi] [smallint] NOT NULL,
	[KayitBitisTarihi] [datetime] NOT NULL,
	[PersonelID] [int] NOT NULL,
	[Yil] [int] NOT NULL,
	[ToplamUcret] [float] NOT NULL,
 CONSTRAINT [PK_Ucret] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Veli]

-- %%
/****** Object:  Table [dbo].[Veli]    Script Date: 18.01.2022 23:13:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Veli](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ad] [nvarchar](50) NOT NULL,
	[Soyad] [nvarchar](50) NOT NULL,
	[YakinlikDerecesi] [nvarchar](50) NULL,
	[Telefon] [nvarchar](11) NOT NULL,
	[OgrenciID] [int] NOT NULL,
 CONSTRAINT [PK_Veli] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Oda]

-- %%
SET IDENTITY_INSERT [dbo].[Oda] ON 
INSERT [dbo].[Oda] ([Id], [OdaNo], [KisiSayisi], [Durum]) VALUES (1, N'1', 4, 1)
INSERT [dbo].[Oda] ([Id], [OdaNo], [KisiSayisi], [Durum]) VALUES (2, N'z006', 6, 1)
INSERT [dbo].[Oda] ([Id], [OdaNo], [KisiSayisi], [Durum]) VALUES (3, N'204', 4, 1)
INSERT [dbo].[Oda] ([Id], [OdaNo], [KisiSayisi], [Durum]) VALUES (4, N'205', 4, 1)
SET IDENTITY_INSERT [dbo].[Oda] OFF
GO

-- %% [markdown]
-- # [dbo].[Odeme]

-- %%
SET IDENTITY_INSERT [dbo].[Odeme] ON 
INSERT [dbo].[Odeme] ([Id], [OdemeTutari], [IslemTarihi], [PersonelID], [UcretID]) VALUES (2, 300, CAST(N'2020-05-14T00:00:06.397' AS DateTime), 1, 2)
INSERT [dbo].[Odeme] ([Id], [OdemeTutari], [IslemTarihi], [PersonelID], [UcretID]) VALUES (6, 100, CAST(N'2020-05-14T00:09:24.047' AS DateTime), 1, 5)
INSERT [dbo].[Odeme] ([Id], [OdemeTutari], [IslemTarihi], [PersonelID], [UcretID]) VALUES (7, 300, CAST(N'2020-05-14T00:43:20.757' AS DateTime), 1, 5)
SET IDENTITY_INSERT [dbo].[Odeme] OFF
GO

-- %% [markdown]
-- # [dbo].[Ogrenci]

-- %%
SET IDENTITY_INSERT [dbo].[Ogrenci] ON 
INSERT [dbo].[Ogrenci] ([Id], [OdaID], [Ad], [Soyad], [TC], [Telefon], [Resim], [KayitTarihi], [OgrenciNo], [OgrSinif], [Durum]) VALUES (1, 2, N'Ali', N'HEPÇALIŞIR', N'87654321989', N'0255556655 ', NULL, CAST(N'2022-01-18T22:09:28.040' AS DateTime), N'123123', 1, 1)
INSERT [dbo].[Ogrenci] ([Id], [OdaID], [Ad], [Soyad], [TC], [Telefon], [Resim], [KayitTarihi], [OgrenciNo], [OgrSinif], [Durum]) VALUES (2, 1, N'Hüseyin', N'YILMAZ', N'23423423412', N'03381234545', NULL, CAST(N'2022-01-18T22:10:09.340' AS DateTime), N'455555i', 2, 0)
SET IDENTITY_INSERT [dbo].[Ogrenci] OFF
GO

-- %% [markdown]
-- # [dbo].[Personel]

-- %%
SET IDENTITY_INSERT [dbo].[Personel] ON 
INSERT [dbo].[Personel] ([Id], [Ad], [Soyad], [Telefon], [KullaniciAdi], [Sifre], [KayitTarihi], [Durum]) VALUES (1, N'M.Yasin', N'Özcan', N' 1213213123', N'myasin', N'123', CAST(N'2022-01-18T19:15:46.673' AS DateTime), 1)
SET IDENTITY_INSERT [dbo].[Personel] OFF
GO

-- %% [markdown]
-- # [dbo].[Ucret]

-- %%
SET IDENTITY_INSERT [dbo].[Ucret] ON 
INSERT [dbo].[Ucret] ([Id], [OgrenciID], [KayitBaslangicTarihi], [TaksitSayisi], [KayitBitisTarihi], [PersonelID], [Yil], [ToplamUcret]) VALUES (2, 2, CAST(N'2021-09-22T00:00:00.000' AS DateTime), 9, CAST(N'2022-07-05T00:00:00.000' AS DateTime), 1, 2021, 3.5)
INSERT [dbo].[Ucret] ([Id], [OgrenciID], [KayitBaslangicTarihi], [TaksitSayisi], [KayitBitisTarihi], [PersonelID], [Yil], [ToplamUcret]) VALUES (5, 1, CAST(N'2021-02-05T00:00:00.000' AS DateTime), 5, CAST(N'2022-06-07T00:00:00.000' AS DateTime), 1, 2020, 2)
INSERT [dbo].[Ucret] ([Id], [OgrenciID], [KayitBaslangicTarihi], [TaksitSayisi], [KayitBitisTarihi], [PersonelID], [Yil], [ToplamUcret]) VALUES (16, 1, CAST(N'2021-12-30T00:00:00.000' AS DateTime), 7, CAST(N'2022-01-06T00:00:00.000' AS DateTime), 1, 2022, 2.5)
INSERT [dbo].[Ucret] ([Id], [OgrenciID], [KayitBaslangicTarihi], [TaksitSayisi], [KayitBitisTarihi], [PersonelID], [Yil], [ToplamUcret]) VALUES (17, 2, CAST(N'2021-12-30T00:00:00.000' AS DateTime), 8, CAST(N'2022-01-06T00:00:00.000' AS DateTime), 1, 2022, 0.5)
SET IDENTITY_INSERT [dbo].[Ucret] OFF
GO

-- %% [markdown]
-- # [dbo].[Veli]

-- %%
SET IDENTITY_INSERT [dbo].[Veli] ON 
INSERT [dbo].[Veli] ([Id], [Ad], [Soyad], [YakinlikDerecesi], [Telefon], [OgrenciID]) VALUES (3, N'veli', N'soy', N'baba', N' 1213213123', 1)
INSERT [dbo].[Veli] ([Id], [Ad], [Soyad], [YakinlikDerecesi], [Telefon], [OgrenciID]) VALUES (6, N'veliye', N'v', N'baba', N'1', 2)
SET IDENTITY_INSERT [dbo].[Veli] OFF
GO

-- %% [markdown]
-- # [IX_Personel]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [IX_Personel]    Script Date: 18.01.2022 23:13:36 ******/
ALTER TABLE [dbo].[Personel] ADD  CONSTRAINT [IX_Personel] UNIQUE NONCLUSTERED 
(
	[KullaniciAdi] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
GO

-- %% [markdown]
-- # [IX_Ucret]

-- %%
/****** Object:  Index [IX_Ucret]    Script Date: 18.01.2022 23:13:36 ******/
ALTER TABLE [dbo].[Ucret] ADD  CONSTRAINT [IX_Ucret] UNIQUE NONCLUSTERED 
(
	[OgrenciID] ASC,
	[Yil] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
GO

-- %% [markdown]
-- # [IX_Veli]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [IX_Veli]    Script Date: 18.01.2022 23:13:36 ******/
ALTER TABLE [dbo].[Veli] ADD  CONSTRAINT [IX_Veli] UNIQUE NONCLUSTERED 
(
	[OgrenciID] ASC,
	[YakinlikDerecesi] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Log_Personel]

-- %%
ALTER TABLE [dbo].[Log]  WITH CHECK ADD  CONSTRAINT [FK_Log_Personel] FOREIGN KEY([PersonelID])
REFERENCES [dbo].[Personel] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Log] CHECK CONSTRAINT [FK_Log_Personel]
GO

-- %% [markdown]
-- # [FK_Odeme_Personel]

-- %%
ALTER TABLE [dbo].[Odeme]  WITH CHECK ADD  CONSTRAINT [FK_Odeme_Personel] FOREIGN KEY([PersonelID])
REFERENCES [dbo].[Personel] ([Id])
GO
ALTER TABLE [dbo].[Odeme] CHECK CONSTRAINT [FK_Odeme_Personel]
GO

-- %% [markdown]
-- # [FK_Odeme_Ucret]

-- %%
ALTER TABLE [dbo].[Odeme]  WITH CHECK ADD  CONSTRAINT [FK_Odeme_Ucret] FOREIGN KEY([UcretID])
REFERENCES [dbo].[Ucret] ([Id])
GO
ALTER TABLE [dbo].[Odeme] CHECK CONSTRAINT [FK_Odeme_Ucret]
GO

-- %% [markdown]
-- # [FK_Ogrenci_Oda]

-- %%
ALTER TABLE [dbo].[Ogrenci]  WITH CHECK ADD  CONSTRAINT [FK_Ogrenci_Oda] FOREIGN KEY([OdaID])
REFERENCES [dbo].[Oda] ([Id])
GO
ALTER TABLE [dbo].[Ogrenci] CHECK CONSTRAINT [FK_Ogrenci_Oda]
GO

-- %% [markdown]
-- # [FK_Ucret_Ogrenci]

-- %%
ALTER TABLE [dbo].[Ucret]  WITH CHECK ADD  CONSTRAINT [FK_Ucret_Ogrenci] FOREIGN KEY([OgrenciID])
REFERENCES [dbo].[Ogrenci] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ucret] CHECK CONSTRAINT [FK_Ucret_Ogrenci]
GO

-- %% [markdown]
-- # [FK_Ucret_Personel]

-- %%
ALTER TABLE [dbo].[Ucret]  WITH CHECK ADD  CONSTRAINT [FK_Ucret_Personel] FOREIGN KEY([PersonelID])
REFERENCES [dbo].[Personel] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Ucret] CHECK CONSTRAINT [FK_Ucret_Personel]
GO

-- %% [markdown]
-- # [FK_Veli_Ogrenci]

-- %%
ALTER TABLE [dbo].[Veli]  WITH CHECK ADD  CONSTRAINT [FK_Veli_Ogrenci] FOREIGN KEY([OgrenciID])
REFERENCES [dbo].[Ogrenci] ([Id])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[Veli] CHECK CONSTRAINT [FK_Veli_Ogrenci]
GO

-- %% [markdown]
-- # [OgrYurt]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [OgrYurt] SET  READ_WRITE 
GO
